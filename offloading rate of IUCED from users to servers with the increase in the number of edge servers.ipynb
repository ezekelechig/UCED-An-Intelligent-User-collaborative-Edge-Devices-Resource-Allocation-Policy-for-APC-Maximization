# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
f=plt.figure()

x=[2,4,6,8,10,12,14]
y=[29,41,52,61,65,67,70]
plt.plot(x,y,label="Offloading rate of IUCED fom users to server")




plt.xlabel("The number of available edge servers")
plt.ylabel("Average Service Latency(ms)")
plt.legend()
plt.show()
f.savefig("graphsu66.pdf",bbox_inches='tight',dpi=600)
