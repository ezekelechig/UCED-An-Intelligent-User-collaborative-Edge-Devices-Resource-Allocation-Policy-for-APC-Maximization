# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
f=plt.figure()

x1=[3.19,6.38,9.57,12.76,15.95,19.14]
y1=[140,120,112,105,104,102]
plt.plot(x1,y1,label="Random search")
x2=[3.19,6.38,9.57,12.76,15.95,19.14]
y2=[120,100,88,85,80,79]
plt.plot(x2,y2,label="Greedy search")
x3=[3.19,6.38,9.57,12.76,15.95,19.14]
y3=[100,80,69,65,64,63]
plt.plot(x3,y3,label="deep Q-learning")
x4=[3.19,6.38,9.57,12.76,15.95,19.14]
y4=[79,60,51,50,45,41]
plt.plot(x4,y4,label="IUCED")



plt.xlabel("The computing capability of Edge servers")
plt.ylabel("Average Service Latency(ms)")
plt.legend()
plt.show()
f.savefig("graphsu33.pdf",bbox_inches='tight',dpi=600)
