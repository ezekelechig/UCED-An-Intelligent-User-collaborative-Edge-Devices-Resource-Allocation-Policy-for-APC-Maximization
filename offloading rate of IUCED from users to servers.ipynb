# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
f=plt.figure()

x=[10,60,110,160,210,260]
y=[88,86,83,80,70,55]
plt.plot(x,y,label="offloading rate of IUCED from users to servers")

plt.xlabel("The number of users")
plt.ylabel("Average Service Latency(ms)")
plt.legend()
plt.show()
f.savefig("graphsu88.pdf",bbox_inches='tight',dpi=600)
