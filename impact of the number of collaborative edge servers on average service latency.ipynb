# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
f=plt.figure()

x1=[2,4,6,8,10,12,14]
y1=[71,69,67,65,62,60,57]
plt.plot(x1,y1,label="Random search")
x2=[2,4,6,8,10,12,14]
y2=[65,58,55,53,52,51,49]
plt.plot(x2,y2,label="Greedy search")
x3=[2,4,6,8,10,12,14]
y3=[52,45,41,39,38,36,34]
plt.plot(x3,y3,label="deep Q-learning")
x4=[2,4,6,8,10,12,14]
y4=[35,26,16,13,10.5,7,5]
plt.plot(x4,y4,label="IUCED")



plt.xlabel("The number of available Edge servers")
plt.ylabel("Average Service Latency(ms)")
plt.legend()
plt.show()
f.savefig("graphsu15.pdf",bbox_inches='tight',dpi=600)
