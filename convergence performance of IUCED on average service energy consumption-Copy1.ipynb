# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
f=plt.figure()
x1=[400,800,1200,1600,2000,2400,2800,3200,3600,4000,4400,4800,5200,5600,6000,6400,6800,7200,7600,8000,8400,8800,9200,9600,10000]
y1=[14.2,12.4,11.7,10.2,9.1,7.8,7,6.4,6.4,6.3,6.2,6.2,6.3,6.2,6.3,6.4,6.5,6.3,6.2,6.3,6.4,5.7,5.7,5.7,5.7]
plt.plot(x1,y1,label="Edge server computing capability=12.76GHz")
x2=[400,800,1200,1600,2000,2400,2800,3200,3600,4000,4400,4800,5200,5600,6000,6400,6800,7200,7600,8000,8400,8800,9200,9600,10000]
y2=[10.4,9.3,8.5,7.5,6.6,5.6,5.2,4.7,4.4,4.3,4.3,4,3.9,3.8,4.2,4.1,4.1,4.4,4.2,4.3,4.2,4.1,4.2,4.2,4.2]
plt.plot(x2,y2,label="Edge server computing capability =19.14GHz")

plt.xlabel("Iteration times")
plt.ylabel("Average Energy consumption(J)")
plt.legend()
plt.show()
f.savefig("graphsu2.pdf",bbox_inches='tight',dpi=600)
