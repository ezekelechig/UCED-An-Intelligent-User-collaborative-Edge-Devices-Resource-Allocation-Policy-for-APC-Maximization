# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
f=plt.figure()

x1=[10,60,110,160,260]
y1=[90,100,110,120,168]
plt.plot(x1,y1,label="Random search")
x2=[10,60,110,160,260]
y2=[72,82,95,102,140]
plt.plot(x2,y2,label="Greedy search")
x3=[10,60,110,160,260]
y3=[50,61,69,82,118]
plt.plot(x3,y3,label="deep Q-learning")
x4=[10,60,110,160,260]
y4=[23,30,36,39,78]
plt.plot(x4,y4,label="IUCED")



plt.xlabel("The number of users")
plt.ylabel("Average Service Latency(ms)")
plt.legend()
plt.show()
f.savefig("graphsu77.pdf",bbox_inches='tight',dpi=600)
