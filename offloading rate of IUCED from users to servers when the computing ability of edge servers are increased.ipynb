# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
f=plt.figure()

x=[3.19,6.38,9.57,12.76,15.95,19.14]
y=[59,90,112,123,129,132]
plt.plot(x,y,label="Offloading rate of IUCED fom users to server")




plt.xlabel("The computing capability of Edge servers")
plt.ylabel("Average Service Latency(ms)")
plt.legend()
plt.show()
f.savefig("graphsu4.pdf",bbox_inches='tight',dpi=600)
